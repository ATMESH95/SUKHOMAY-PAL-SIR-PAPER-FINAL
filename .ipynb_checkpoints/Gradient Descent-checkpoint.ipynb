# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('training.csv')

# %%
df2 = pd.read_csv('testing.csv')

# %%
df.head()
# Out:
#    Experiment no.  Back-ground voltage (V)  Pulse voltage (V)  \
# 0               1                       17               34.6
# 1               2                       17               34.6
# 2               3                       14               30.0
# 3               4                       14               39.0
# 4               5                       14               30.0
#
#    Pulse frequency (Hz)  Pulse duty factor  Wire feed rate (m/min)  \
# 0                   130               0.50                       9
# 1                   130               0.50                       9
# 2                    80               0.35                      11
# 3                    80               0.35                       7
# 4                   182               0.65                      11
#
#    Table feed rate(mm/s)  RMS current (V)  RMS voltage (V)  UTS (Mpa)
# 0                  3.760           1.1939           2.7429     412.28
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalar_X = MinMaxScaler()
scalar_Y = MinMaxScaler()

# %%
X_train = df.drop(['Experiment no.','UTS (Mpa)'],axis=1)

# %%
y_train = df[['UTS (Mpa)']]

# %%
X_train  = scalar_X.fit_transform(X_train)
y_train = scalar_Y.fit_transform(y_train)

# %%
X_test = df2.drop(['Experiment no.','UTS (Mpa)'],axis=1)
y_test = df2[['UTS (Mpa)']]

# %%
X_test = scalar_X.transform(X_test)
y_test = scalar_Y.transform(y_test)

# %%
X_train.shape
# Out:
# (46, 8)

# %%
inputs = keras.Input(shape = (8))
x = layers.Dense(8,activation='relu',kernel_regularizer=keras.regularizers.l2(0.01),bias_initializer='zeros')(inputs)
layer1 = layers.Dense(18,activation='relu',kernel_regularizer=keras.regularizers.l2(0.01),bias_initializer='ones')(x)
layer2 = layers.Dense(20,activation='relu',kernel_regularizer=keras.regularizers.l2(0.01),bias_initializer='ones')(layer1)
output = layers.Dense(1)(layer2)
model = keras.Model(inputs,output)
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 8)]               0
#
#  dense (Dense)               (None, 8)                 72
#
#  dense_1 (Dense)             (None, 18)                162
#
#  dense_2 (Dense)             (None, 20)                380
#
#  dense_3 (Dense)             (None, 1)                 21
#
# ...
# Total params: 635
# Trainable params: 635
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss=keras.losses.MeanSquaredError(),optimizer = keras.optimizers.SGD(learning_rate=0.00009,momentum=0.003),metrics=['mse'])

# %%
history = model.fit(X_train,y_train,epochs=2800,verbose=2,validation_data=(X_test,y_test))
#model.evaluate(X_test,y_test)
# Out:
# Epoch 1/2800
# 2/2 - 1s - loss: 16.3172 - mse: 15.9119 - val_loss: 16.3130 - val_mse: 15.9077 - 529ms/epoch - 265ms/step
# Epoch 2/2800
# 2/2 - 0s - loss: 15.3316 - mse: 14.9263 - val_loss: 15.3521 - val_mse: 14.9470 - 26ms/epoch - 13ms/step
# Epoch 3/2800
# 2/2 - 0s - loss: 14.4189 - mse: 14.0137 - val_loss: 14.4587 - val_mse: 14.0536 - 23ms/epoch - 11ms/step
# Epoch 4/2800
# 2/2 - 0s - loss: 13.5567 - mse: 13.1516 - val_loss: 13.6000 - val_mse: 13.1949 - 22ms/epoch - 11ms/step
# Epoch 5/2800
# 2/2 - 0s - loss: 12.7334 - mse: 12.3283 - val_loss: 12.7915 - val_mse: 12.3864 - 22ms/epoch - 11ms/step
# Epoch 6/2800
# 2/2 - 0s - loss: 11.9692 - mse: 11.5641 - val_loss: 12.0592 - val_mse: 11.6542 - 23ms/epoch - 12ms/step
# Epoch 7/2800
# 2/2 - 0s - loss: 11.2687 - mse: 10.8637 - val_loss: 11.3679 - val_mse: 10.9629 - 27ms/epoch - 14ms/step
# Epoch 8/2800
# 2/2 - 0s - loss: 10.6046 - mse: 10.1996 - val_loss: 10.7018 - val_mse: 10.2968 - 23ms/epoch - 12ms/step
# Epoch 9/2800
# ...

# %%
pre = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 70ms/step

# %%
p= scalar_Y.inverse_transform(pre)

# %%
p
# Out:
# array([[411.70767],
#        [353.6373 ],
#        [447.74722],
#        [420.69553],
#        [157.18054],
#        [354.37354],
#        [386.8004 ]], dtype=float32)

# %%
Y_test=scalar_Y.inverse_transform(y_test)

# %%
Y_test
# Out:
# array([[265.93],
#        [410.64],
#        [453.11],
#        [367.01],
#        [445.03],
#        [413.43],
#        [349.2 ]])

# %%
y_test
# Out:
# array([[0.57337214],
#        [0.88538163],
#        [0.97695127],
#        [0.79131091],
#        [0.95952997],
#        [0.89139715],
#        [0.75291074]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,pre)
# Out:
# 0.076485697014106

# %%
losses = model.history.history

# %%
loss = pd.DataFrame(losses)

# %%
import  matplotlib.pyplot as plt

# %%
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'],color='r')
plt.xlabel('epoch')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])
